# %% [markdown]
# # ECG Feature Extractor
# ## 2017 Physionet Challenge
# ### Sebastian D. Goodfellow, Ph.D.

# %% [markdown]
# # Setup Notebook

# %%
# Import 3rd party libraries
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# Import local Libraries
sys.path.insert(0, os.path.dirname(os.getcwd()))
from features.feature_extractor import Features
from utils.plotting.waveforms import plot_waveforms

# Configure Notebook
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# <br>
# # Set Constants

# %%
# Sampling frequency (Hz)
fs = 300  

# Data paths
label_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'labels')
waveform_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'waveforms')
feature_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'features')

# %% [markdown]
# # Import ECG Labels

# %%
# Read labels CSV
labels = pd.read_csv(os.path.join(label_path, 'labels.csv'), names=['file_name', 'label'])

# View DataFrame
labels.head(10)
# Out:
#   file_name label
# 0    A00021     N
# 1    A00022     ~
# 2    A00023     O
# 3    A00024     O
# 4    A00025     N
# 5    A00026     N
# 6    A00027     A
# 7    A00028     N
# 8    A00029     O
# 9    A00030     O

# %% [markdown]
# # Plot ECG Waveforms

# %%
# Launch interactive plotting widget
plot_waveforms(labels=labels, waveform_path=waveform_path, fs=fs)
# Out:
# interactive(children=(IntSlider(value=4, description='index', max=9), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# # Extract Features

# %%
# Instantiate
ecg_features = Features(file_path=waveform_path, fs=fs, feature_groups=['full_waveform_features'])

# Calculate ECG features
ecg_features.extract_features(
    filter_bandwidth=[3, 45], n_signals=None, show=True, 
    labels=labels, normalize=True, polarity_check=True,
    template_before=0.25, template_after=0.4
)
# Out:
# Finished extracting features from A00021.mat | Extraction time: 0.001 minutes
# Finished extracting features from A00022.mat | Extraction time: 0.001 minutes
# Finished extracting features from A00023.mat | Extraction time: 0.001 minutes
# Finished extracting features from A00024.mat | Extraction time: 0.001 minutes
# Finished extracting features from A00025.mat | Extraction time: 0.001 minutes
# Finished extracting features from A00026.mat | Extraction time: 0.001 minutes
# Finished extracting features from A00027.mat | Extraction time: 0.001 minutes
# Finished extracting features from A00028.mat | Extraction time: 0.001 minutes
# Finished extracting features from A00029.mat | Extraction time: 0.001 minutes
# Finished extracting features from A00030.mat | Extraction time: 0.001 minutes

# %%
# Get features DataFrame
features = ecg_features.get_features()

# View DataFrame
features.head(10)
# Out:
#   file_name label  full_waveform_duration  full_waveform_kurtosis  \
# 0    A00021     N               29.993334               17.586632
# 1    A00022     ~               29.993334              186.943393
# 2    A00023     O               29.993334               23.806715
# 3    A00024     O               29.993334               16.755881
# 4    A00025     N               29.993334               20.460997
# 5    A00026     N               29.993334               26.423581
# 6    A00027     A               29.993334                4.182249
# 7    A00028     N               59.993334               24.053043
# 8    A00029     O               29.993334               12.911929
# 9    A00030     O               59.993334               17.591774
#
#    full_waveform_max  full_waveform_mean  full_waveform_median  \
# 0           1.078687           -0.001071             -0.005645
# 1          11.336603            0.005920             -0.015021
# 2           1.084203            0.001047             -0.001793
# 3           1.127383            0.000431             -0.009887
# 4           1.099219            0.001304             -0.005782
# 5           1.088726            0.000484             -0.005873
# 6           1.142597           -0.004536             -0.008124
# 7           1.058158            0.000643             -0.003022
# 8           1.201930            0.001085              0.008018
# 9           1.122591           -0.000551             -0.002507
#
#    full_waveform_min  full_waveform_skew  full_waveform_std  \
# 0          -0.926257            1.123091           0.168382
# 1          -3.053789            8.539399           0.448065
# 2          -0.569955            3.847851           0.147708
# 3          -0.460385            3.331231           0.164943
# 4          -0.376020            3.705835           0.148803
# 5          -0.300124            4.351558           0.138428
# 6          -1.261730           -0.093087           0.295540
# 7          -0.400153            4.127633           0.146124
# 8          -1.129869            1.003582           0.204132
# 9          -1.394709            0.832302           0.171259
#
#             ...             swt_d_3_energy_entropy  swt_d_3_high_power_ratio  \
# 0           ...                      -49257.007497                  0.165148
# 1           ...                      -29308.911535                  0.101234
# 2           ...                      -50412.226570                  0.140089
# 3           ...                      -47704.749291                  0.160745
# 4           ...                      -51189.042010                  0.140490
# 5           ...                      -53693.449870                  0.163446
# 6           ...                      -42018.523028                  0.107055
# 7           ...                     -107837.970823                  0.218004
# 8           ...                      -43041.145948                  0.145105
# 9           ...                      -99939.554307                  0.162480
#
#    swt_d_3_higuchi_fractal  swt_d_3_low_power_ratio  swt_d_3_med_power_ratio  \
# 0                 1.603244                 0.861031                 0.106582
# 1                 1.681422                 0.818841                 0.103232
# 2                 1.652927                 0.891568                 0.118739
# 3                 1.552763                 0.713365                 0.086996
# 4                 1.629942                 0.619724                 0.101542
# 5                 1.598554                 0.730220                 0.104961
# 6                 1.604812                 0.598398                 0.115260
# 7                 1.514557                 0.832327                 0.092834
# 8                 1.659092                 0.654917                 0.133569
# 9                 1.610238                 0.847671                 0.107021
#
#    swt_d_4_energy_entropy  swt_d_4_high_power_ratio  swt_d_4_higuchi_fractal  \
# 0           -67495.761089                  0.112211                 1.745630
# 1           -47754.339321                  0.122283                 1.850699
# 2           -68218.166248                  0.098615                 1.796991
# 3           -66148.672913                  0.106267                 1.703458
# 4           -69002.674228                  0.097502                 1.784161
# 5           -72170.234663                  0.110092                 1.743084
# 6           -60561.603002                  0.098163                 1.776238
# 7          -144336.658169                  0.156514                 1.640446
# 8           -60798.823282                  0.101870                 1.794644
# 9          -136124.687363                  0.113337                 1.756203
#
#    swt_d_4_low_power_ratio  swt_d_4_med_power_ratio
# 0                 0.876491                 0.139795
# 1                 0.833149                 0.127526
# 2                 0.905369                 0.160293
# 3                 0.729247                 0.107630
# 4                 0.633528                 0.139208
# 5                 0.746238                 0.136632
# 6                 0.612691                 0.103083
# 7                 0.846448                 0.105700
# 8                 0.667569                 0.176868
# 9                 0.861335                 0.142411
#
# [10 rows x 50 columns]

# %% [markdown]
# <br>
# # Save Features

# %%
# Save features DataFrame to CSV
features.to_csv(os.path.join(feature_path, 'features.csv'), index=False)
