# %% [markdown]
# # ECG Feature Extractor
# ## 2017 Physionet Challenge
# ### Sebastian D. Goodfellow, Ph.D.

# %% [markdown]
# # Setup Notebook

# %%
# Import 3rd party libraries
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# Import local Libraries
sys.path.insert(0, os.path.dirname(os.getcwd()))
from utils.plotting.waveforms import plot_waveforms

# Configure Notebook
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# <br>
# # Set Constants

# %%
# Sampling frequency (Hz)
fs = 300  

# Data paths
label_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'labels')
waveform_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'waveforms')

# %% [markdown]
# # Import ECG Labels

# %%
# Read labels CSV
labels = pd.read_csv(os.path.join(label_path, 'labels.csv'), names=['name', 'label'])

# View DataFrame
labels.head(10)
# Out:
#      name label
# 0  A00021     N
# 1  A00022     ~
# 2  A00023     O
# 3  A00024     O
# 4  A00025     N
# 5  A00026     N
# 6  A00027     A
# 7  A00028     N
# 8  A00029     O
# 9  A00030     O

# %% [markdown]
# # Plot ECG Waveforms

# %%
# Launch interactive plotting widget
plot_waveforms(labels=labels, waveform_path=waveform_path, fs=fs)
# Out:
# interactive(children=(IntSlider(value=4, description='index', max=9), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# <br>
# # Compute Features

# %%
# Print feature group list
prt = [print(method) for method in Features.get_feature_groups()]
# Out:
# full_waveform_statistics
# heart_rate_variability_statistics
# template_statistics

# %%
# Instantiate Features object
ecg_features = Features(

    file_path = ecg_file_path,
    fs = fs,
    feature_groups = [   
        'full_waveform_statistics',
        'heart_rate_variability_statistics',
        'template_statistics'
    ]

)

# %%
# Calculate ECG features
ecg_features.calculate_features(
    filter_bandwidth=[3, 45], n_signals=None, show=False, 
    labels_file_path=labels_file_path, normalize=True, polarity_check=True,
    template_before=0.25, template_after=0.4
)

# %%
# Get features DataFrame
features = ecg_features.get_features()

# View DataFrame
features.head(10)
# Out:
#   file_name label  detection_success  diff2_rri_activity  \
# 0    A00001     N           0.975000            0.001046
# 1    A00002     N           1.161290            0.153141
# 2    A00003     N           0.987805            0.011694
# 3    A00004     A           0.939394            0.146486
# 4    A00005     A           0.827068            0.174570
# 5    A00006     N           0.965517            0.001480
# 6    A00007     N           0.937500            0.000797
# 7    A00008     O           1.000000            0.214572
# 8    A00009     A           0.979167            0.067731
# 9    A00010     N           0.984848            0.000273
#
#    diff2_rri_approximate_entropy  diff2_rri_complexity  diff2_rri_fisher_info  \
# 0                      -0.092783              1.567086               0.032062
# 1                       0.058072              1.711867               0.078872
# 2                       0.705230              1.689865               0.075959
# 3                      -0.164503              1.767614               0.129440
# 4                       0.202174              1.745121               0.124059
# 5                      -0.120462              1.592431               0.044124
# 6                      -0.114093              1.408019               0.000969
# 7                       0.368123              1.850788               0.229010
# 8                      -0.113083              1.828891               0.199274
# 9                       0.030481              1.668360               0.065314
#
#    diff2_rri_hurst_exponent  diff2_rri_kurtosis  diff2_rri_max  \
# 0                  1.059320           -0.846983       0.066667
# 1                  1.061292            0.861128       1.016667
# 2                  1.052955           12.446644       0.543333
# 3                  1.073740           -0.537768       0.823333
# 4                  1.055845            1.029453       0.750000
# 5                  1.062367           -0.609967       0.080000
# 6                  1.085469           -0.661834       0.050000
# 7                  1.067438            1.305744       1.173333
# 8                  1.070217           -0.686893       0.470000
# 9                  1.061682           -0.501353       0.040000
#
#             ...             t_wave_shannon_entropy_median  \
# 0           ...                                  6.321928
# 1           ...                                  6.321928
# 2           ...                                  6.321928
# 3           ...                                  6.321928
# 4           ...                                  6.321928
# 5           ...                                  6.321928
# 6           ...                                  6.321928
# 7           ...                                  6.321928
# 8           ...                                  6.321928
# 9           ...                                  6.321928
#
#    t_wave_shannon_entropy_std  t_wave_svd_entropy_mean  \
# 0                2.699367e-15                 0.581594
# 1                1.801555e-15                 0.626408
# 2                8.937123e-16                 0.575083
# 3                3.611440e-15                 0.494476
# 4                2.676843e-15                 0.620182
# 5                2.713430e-15                 0.508584
# 6                2.710086e-15                 0.514739
# 7                0.000000e+00                 0.577000
# 8                8.979928e-16                 0.610575
# 9                8.951997e-16                 0.518520
#
#    t_wave_svd_entropy_median  t_wave_svd_entropy_std  t_wave_time  \
# 0                   0.585435                0.031599     0.473333
# 1                   0.588139                0.121808     0.516667
# 2                   0.572425                0.057974     0.486667
# 3                   0.493509                0.025508     0.523333
# 4                   0.588169                0.136537     0.476667
# 5                   0.504839                0.015945     0.583333
# 6                   0.515056                0.012724     0.523333
# 7                   0.566381                0.053073     0.503333
# 8                   0.613608                0.054971     0.513333
# 9                   0.519470                0.018830     0.520000
#
#    t_wave_time_std  template_corr_coeff_mean  template_corr_coeff_median  \
# 0         0.000045                  0.978165                    0.988007
# 1         0.000230                  0.743351                    0.868471
# 2         0.000103                  0.902924                    0.953701
# 3         0.000032                  0.978714                    0.981759
# 4         0.000275                  0.781643                    0.762172
# 5         0.000018                  0.982199                    0.985938
# 6         0.000016                  0.988286                    0.991568
# 7         0.000148                  0.942728                    0.967197
# 8         0.000175                  0.838192                    0.928010
# 9         0.000080                  0.979496                    0.985151
#
#    template_corr_coeff_std
# 0                 0.031278
# 1                 0.249129
# 2                 0.117481
# 3                 0.011892
# 4                 0.178191
# 5                 0.013866
# 6                 0.010011
# 7                 0.064819
# 8                 0.318490
# 9                 0.019782
#
# [10 rows x 297 columns]

# %% [markdown]
# <br>
# # Save Features

# %%
# Set file path
path = r'C:\Users\sgoodfellow\Documents\Sebastian\Data Science\PhysioNet\Code\Submissions\Submission 11'
file = 'features_filt_3_45_submission_11.pickle'

# Pickel Model
with open(os.path.join(path, file), 'wb') as f:
    pickle.dump(features, f)
